# %% [markdown]
# **Generative AI (LLMs, RAG, Fine-tuning)**
#
#
# **Easy**
#
# 1. What is an LLM?
# 2. What is a Transformer?
# 3. What are tokens?
# 4. What is tokenization?
# 5. What is an embedding?
#
# **Medium**
#
# 6. What is RAG?
# 7. When do you use RAG instead of fine-tuning?
# 8. What is a vector database?
# 9. What is semantic search?
# 10. What is chunking?
#
# **Hard**
#
# 11. Explain a RAG architecture to a non-technical stakeholder.
# 12. Reduce hallucinations in a RAG system.
# 13. Reduce mode collapse after fine-tuning.
# 14. Build a chatbot using RAG.
# 15. Design a multi-document QA system.
