# %%
words = ['eat', 'tea', 'tan', 'ate', 'ant', 'bat']

groups ={}

for word in words:
    key = "".join(sorted(word))

    if key not in groups:
        groups[key] = []
    groups[key].append(word)

print(list(groups.values()))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'ant'], ['bat']]

# %%
nums = [2, 7, 11, 15]
target = 9

for i in range(len(nums)):
    print(i)
    for j in range(i+1, len(nums)):
        print(j)
        if nums[i] + nums[j] == target:
            print([i,j])
# Out:
# 0
# 1
# [0, 1]
# 2
# 3
# 1
# 2
# 3
# 2
# 3
# 3

# %%
nums = [2, 7, 11, 15]
target = 9

seen ={}

for i in range(len(nums)):
    current = nums[i]

    completeness = target - current
    if completeness in seen:
        print(seen[completeness], i)
        break
    seen[completeness]=i

# %%
seen
# Out:
# {7: 0, 2: 1, -2: 2, -6: 3}

# %%
cache = {}

# %%
type(cache)
# Out:
# dict

# %%
cache
# Out:
# {}

# %%
cache[0] = 'A'

# %%
cache[1] = 'B'

# %%
cache[2] = 'C'

# %%
cache
# Out:
# {0: 'A', 1: 'B', 2: 'C'}

# %%
len(cache)
# Out:
# 3

# %%
capacity = 3

# %%
len(cache) == capacity
# Out:
# True

# %%
value= cache.pop(1)

# %%
cache
# Out:
# {0: 'A', 2: 'C'}

# %%
value
# Out:
# 'B'

# %%
cache[1] = value

# %%
cache
# Out:
# {0: 'A', 2: 'C', 1: 'B'}

# %%
next(iter(cache))
# Out:
# 0

# %%
cache.pop(next(iter(cache)))
# Out:
# 'A'

# %%
cache.pop(next(iter(cache)))
# Out:
# 'C'

# %%
cache.pop(next(iter(cache)))
# Out:
# 'B'

# %%
cache.pop(next(iter(cache)))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 cache.pop(next(iter(cache)))
#
# StopIteration:

# %%
cache[3] = "D"

# %%
cache
# Out:
# {3: 'D'}

# %%
# Out:
# {1: 'A', 2: 'B', 3: 'C'}
# {1: 'A', 3: 'C', 2: 'B'}
# {3: 'C', 2: 'B', 4: 'D'}

# %%
capacity = 3

# %%
cache = {}

# %%
cache[0] = 'A'
cache[1] = 'B'
cache[2] = 'C'

# %%
cache
# Out:
# {0: 'A', 1: 'B', 2: 'C'}

# %%
value = cache.pop(1)
cache[1] = value

# %%
cache
# Out:
# {0: 'A', 2: 'C', 1: 'B'}

# %%
if len(cache) == capacity:
    cache.pop(next(iter(cache)))

print(cache)
# Out:
# {0: 'A', 2: 'C', 1: 'B', 4: 'D'}

# %%
cache
# Out:
# {0: 'A', 2: 'C', 1: 'B', 4: 'D'}

# %%
text = "python is easy python is powerful"

# %%
type(text)
# Out:
# str

# %%
type(text.split())
# Out:
# list

# %%
word = text.split()

# %%
frequency = {}

# %%
for i in word:
    if i in frequency:
        frequency[i]+=1 
    else:
        frequency[i] = 1
    print(i)
print(frequency)
# Out:
# python
# is
# easy
# python
# is
# powerful
# {'python': 2, 'is': 2, 'easy': 1, 'powerful': 1}

# %%
matrix = [
    [1,2,3],
    [4,5,6]
]

transpose = []


for col in range(len(matrix[0])):
    new_row = []
    for row in range(len(matrix)):
        new_row.append(matrix[row][col])
    transpose.append(new_row)
print(transpose)
# Out:
# [[1, 4], [2, 5], [3, 6]]

# %%
head = {
    "data": 1,
    "next": {
        "data": 2,
        "next": {
            "data": 3,
            "next": {
                "data": 4,
                "next": None
            }
        }
    }
}

# %%
previous = None

# %%
current = head
current
# Out:
# {'data': 1,
#  'next': {'data': 2, 'next': {'data': 3, 'next': {'data': 4, 'next': None}}}}

# %%
next_node = current['next'] # save next node
next_node
# Out:
# {'data': 2, 'next': {'data': 3, 'next': {'data': 4, 'next': None}}}

# %%
current['next'] = previous # reverse the link
print(current['next'])
# Out:
# None

# %%
previous = current # move pervious
previous
# Out:
# {'data': 1, 'next': None}

# %%
current = next_node
current
# Out:
# {'data': 2, 'next': {'data': 3, 'next': {'data': 4, 'next': None}}}

# %%
head = previous
head
# Out:
# {'data': 1, 'next': None}

# %%
# iternation = 2

# %%
next_node = current['next']
next_node
# Out:
# {'data': 3, 'next': {'data': 4, 'next': None}}

# %%
current['next'] = previous # reverse the link
print(current['next'])
# Out:
# {'data': 1, 'next': None}

# %%
previous = current # move pervious
previous
# Out:
# {'data': 2, 'next': {'data': 1, 'next': None}}

# %%
current = next_node
current
# Out:
# {'data': 3, 'next': {'data': 4, 'next': None}}

# %%
# iternation = 3

# %%
next_node = current['next']
next_node
# Out:
# {'data': 4, 'next': None}

# %%
current['next'] = previous
current['next']
# Out:
# {'data': 2, 'next': {'data': 1, 'next': None}}

# %%
previous = current
previous
# Out:
# {'data': 3, 'next': {'data': 2, 'next': {'data': 1, 'next': None}}}

# %%
current = next_node
current
# Out:
# {'data': 4, 'next': None}

# %%
next_node = current['next']
print(next_node)
# Out:
# None
