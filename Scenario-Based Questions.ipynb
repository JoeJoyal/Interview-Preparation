# %% [markdown]
# **Scenario-Based Questions**
#
# 1. Your model performs well locally but poorly in production. How do you investigate?
# 2. An LLM starts hallucinating after deployment. What steps would you take?
# 3. Your RAG chatbot returns incorrect documents. How do you debug it?
# 4. Users report slow inference. How do you optimize performance?
# 5. Your API receives 10,000 concurrent requests. How would you scale it?
# 6. Your prompt works in development but fails in production. Why?
# 7. A vector database returns irrelevant documents. What could be wrong?
# 8. A PyTorch model gives different predictions every run. Why?
# 9. Your async application is slower than expected. How do you diagnose it?
# 10. A machine learning model drifts over time. How would you monitor and retrain it?
